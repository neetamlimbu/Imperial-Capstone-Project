# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# =========================================================
# 1. WEEKLY DATA (WEEKS 1–12)
# =========================================================

week1_inputs = [
    [0.333333, 0.666667],
    [0.777778, 0.222222],
    [0.142857, 0.571429, 0.857143],
    [0.285714, 0.714286, 0.428571, 0.857143],
    [0.0625, 0.5, 0.9375, 0.25],
    [0.111111, 0.444444, 0.777778, 0.222222, 0.888889],
    [0.090909, 0.363636, 0.636364, 0.181818, 0.545455, 0.818182],
    [0.125, 0.25, 0.375, 0.5, 0.625, 0.75, 0.875, 0.0625]
]

week2_inputs = [
    [0.5, 0.5],
    [0.7, 0.3],
    [0.2, 0.6, 0.8],
    [0.2, 0.8, 0.3, 0.7],
    [0.08, 0.52, 0.92, 0.27],
    [0.2, 0.5, 0.8, 0.3, 0.9],
    [0.12, 0.38, 0.66, 0.22, 0.58, 0.84],
    [0.15, 0.275, 0.4, 0.525, 0.65, 0.775, 0.9, 0.1]
]

week3_inputs = [
    [0.45, 0.55],
    [0.725, 0.275],
    [0.8, 0.2, 0.4],
    [0.25, 0.75, 0.35, 0.65],
    [0.07, 0.51, 0.93, 0.26],
    [0.21, 0.49, 0.81, 0.31, 0.91],
    [0.1, 0.36, 0.64, 0.2, 0.56, 0.82],
    [0.13, 0.26, 0.38, 0.51, 0.63, 0.76, 0.88, 0.07]
]

week4_inputs = [
    [0.427778, 0.572222],
    [0.734259, 0.265741],
    [0.380952, 0.457143, 0.685714],
    [0.245238, 0.754762, 0.359524, 0.735714],
    [0.070833, 0.51, 0.929167, 0.26],
    [0.173704, 0.478148, 0.795926, 0.277407, 0.89963],
    [0.103636, 0.367879, 0.645455, 0.200606, 0.561818, 0.826061],
    [0.135, 0.261667, 0.385, 0.511667, 0.635, 0.761667, 0.885, 0.0775]
]

week5_inputs = [
    [0.42, 0.58],
    [0.63, 0.37],
    [0.31, 0.52, 0.74],
    [0.27, 0.61, 0.44, 0.83],
    [0.18, 0.57, 0.89, 0.33],
    [0.22, 0.48, 0.79, 0.29, 0.91],
    [0.14, 0.39, 0.66, 0.23, 0.58, 0.84],
    [0.16, 0.28, 0.41, 0.53, 0.66, 0.78, 0.9, 0.11]
]

week6_inputs = [
    [0.436555, 0.561852],
    [0.643711, 0.350427],
    [0.290003, 0.526542, 0.748973],
    [0.257349, 0.623142, 0.4314, 0.843698],
    [0.164072, 0.559418, 0.90988, 0.318913],
    [0.203885, 0.477786, 0.796998, 0.271818, 0.890277],
    [0.133556, 0.371272, 0.667798, 0.244733, 0.565004, 0.824401],
    [0.140764, 0.29475, 0.39968, 0.531209, 0.640643, 0.763956, 0.880412, 0.096299]
]

week7_inputs = [
    [0.999509, 0.605025],
]

# WEEKLY OUTPUTS (Week 12 from email)
week12_outputs = [
    0.0,
    0.5801011852624599,
    -0.06398343263504208,
    -28.945019913941298,
    1616.6425,
    -1.477207162159974,
    1.171009318877088,
    9.2523133837576
]

weeks_inputs = [
    week1_inputs, week2_inputs, week3_inputs, week4_inputs,
    week5_inputs, week6_inputs, week7_inputs, week8_inputs,
    week9_inputs, week10_inputs, week11_inputs, week12_inputs
]

weeks_outputs = [
    week1_outputs, week2_outputs, week3_outputs, week4_outputs,
    week5_outputs, week6_outputs, week7_outputs, week8_outputs,
    week9_outputs, week10_outputs, week11_outputs, week12_outputs
]

# =========================================================
# 2. BUILD PER-FUNCTION DATASETS
# =========================================================

n_functions = 8
X_funcs = []
y_funcs = []

for f in range(n_functions):
    X_f = []
    y_f = []
    for w in range(len(weeks_inputs)):
        X_f.append(weeks_inputs[w][f])
        y_f.append(weeks_outputs[w][f])
    X_funcs.append(np.array(X_f, dtype=float))
    y_funcs.append(np.array(y_f, dtype=float))

# =========================================================
# 3. SIMPLE SURROGATE OPTIMISER (RANDOM FOREST + RANDOM SEARCH)
# =========================================================

def propose_next_for_function(X, y, n_candidates=20000, random_state=0):
    d = X.shape[1]
    rf = RandomForestRegressor(
        n_estimators=400,
        random_state=random_state,
        n_jobs=-1
    )
    rf.fit(X, y)

    rng = np.random.RandomState(random_state)
    candidates = rng.rand(n_candidates, d)
    preds = rf.predict(candidates)

    best_idx = np.argmax(preds)
    return candidates[best_idx]

# =========================================================
# 4. GENERATE WEEK 13 INPUTS
# =========================================================

week13_inputs = []

for f in range(n_functions):
    x_star = propose_next_for_function(X_funcs[f], y_funcs[f], random_state=100 + f)
    week13_inputs.append(x_star)

# =========================================================
# 5. PRINT WEEK 13 IN PORTAL FORMAT
# =========================================================

def format_portal(x):
    return " - ".join(f"{v:.6f}" for v in x)

print("\n=== WEEK 13 PROPOSED INPUTS ===")
for i, x in enumerate(week13_inputs, start=1):
    print(f"Function {i}: {format_portal(x)}")
# Out:
# === WEEK 13 PROPOSED INPUTS ===
# Function 1: 0.543405 - 0.278369
# Function 2: 0.716862 - 0.999637
# Function 3: 0.123960 - 0.578788 - 0.858504
# Function 4: 0.594886 - 0.596448 - 0.537881 - 0.387366
# Function 5: 0.984148 - 0.023947 - 0.971181 - 0.047448
# Function 6: 0.581374 - 0.150973 - 0.963215 - 0.157015 - 0.071305
# Function 7: 0.096153 - 0.253981 - 0.682971 - 0.333279 - 0.022387 - 0.824126
# Function 8: 0.004507 - 0.505106 - 0.111635 - 0.477920 - 0.296520 - 0.706214 - 0.590532 - 0.176396
